# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %% [markdown]
# Okay! We're going back to our bike path dataset here. I live in Montreal, and I was curious about whether we're more of a commuter city or a biking-for-fun city -- do people bike more on weekends, or on weekdays?

# %% [markdown]
# # Adding a 'weekday' column to our dataframe

# %%
RawData = 'https://raw.githubusercontent.com/abualhoul44/HTU-DS-2021/main/Data/bikes.csv'

# %%
Broken_data = pd.read_csv(RawData)

# %%
# !wget https://raw.githubusercontent.com/abualhoul44/HTU-DS-2021/main/Data/bikes.csv

# %%
! cat /content/bikes.csv

# %%
bikes.head(2)

# %% [markdown]
# Try calling read_csv with encoding='latin1', encoding='iso-8859-1' or encoding='cp1252' (these are some of the various encodings found on Windows).

# %%
Broken_data = pd.read_csv(RawData, encoding='ISO-8859-1')
#cp1252
#latin1

# %%
Broken_data.head(2)

# %%
Broken_data = pd.read_csv(RawData,encoding='latin1')

# %%
Broken_data.head(2)

# %%
Broken_data = pd.read_csv(RawData,encoding='latin1', sep=';' )

# %%
Broken_data.head(2)
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 0  01/01/2012       35                                NaN                      0             38             51       26            10       16                                  NaN
# 1  02/01/2012       83                                NaN                      1             68            153       53             6       43                                  NaN

# %%
Broken_data = pd.read_csv(RawData, sep=';', encoding='latin1', parse_dates=True )

# %%
Broken_data.head(3)
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 0  01/01/2012       35                                NaN                      0             38             51       26            10       16                                  NaN
# 1  02/01/2012       83                                NaN                      1             68            153       53             6       43                                  NaN
# 2  03/01/2012      135                                NaN                      2            104            248       89             3       58                                  NaN

# %%
Broken_data = pd.read_csv(RawData, sep=';', encoding='latin1', parse_dates=['Date'] )

# %%
Broken_data.head(3)
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 0  01/01/2012       35                                NaN                      0             38             51       26            10       16                                  NaN
# 1  02/01/2012       83                                NaN                      1             68            153       53             6       43                                  NaN
# 2  03/01/2012      135                                NaN                      2            104            248       89             3       58                                  NaN

# %%
Broken_data['Berri 1']
# Out:
# 0        35
# 1        83
# 2       135
# 3       144
# 4       197
#        ...
# 305    2405
# 306    1582
# 307     844
# 308     966
# 309    2247
# Name: Berri 1, Length: 310, dtype: int64

# %%
Broken_data = pd.read_csv(RawData, sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True )

# %%
Broken_data['Date']

# %%
Broken_data.head(2)
# Out:
#         Date  Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 0 2012-01-01       35                                NaN                      0             38             51       26            10       16                                  NaN
# 1 2012-01-02       83                                NaN                      1             68            153       53             6       43                                  NaN

# %%
Broken_data = pd.read_csv(RawData, sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date' )

# %%
Broken_data['Date']

# %%
Broken_data.head(3)
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# Date
# 2012-01-01       35                                NaN                      0             38             51       26            10       16                                  NaN
# 2012-01-02       83                                NaN                      1             68            153       53             6       43                                  NaN
# 2012-01-03      135                                NaN                      2            104            248       89             3       58                                  NaN

# %%
CleanData = Broken_data.to_csv('My1stcsv.csv')

# %%
CleanData = Broken_data.copy()

# %%
CleanData.head(2)
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# Date
# 2012-01-01       35                                NaN                      0             38             51       26            10       16                                  NaN
# 2012-01-02       83                                NaN                      1             68            153       53             6       43                                  NaN

# %%
CleanData['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %%
CleanData['Berri 1'].index.weekofyear
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   """Entry point for launching an IPython kernel.
# Int64Index([52,  1,  1,  1,  1,  1,  1,  1,  2,  2,
#             ...
#             43, 43, 44, 44, 44, 44, 44, 44, 44, 45], dtype='int64', name='Date', length=310)

# %%
CleanData['Berri 1'].plot()

# %%
CleanData['Berri 1'].resample('Q').plot()
# Out:
# Date
# 2012-03-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012-06-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012-09-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# Freq: Q-DEC, Name: Berri 1, dtype: object

# %%
Weekdays=CleanData['Berri 1'].groupby('')

# %% [markdown]
# **end_types = {"M", "A", "Q", "BM", "BA", "BQ", "W"}**

# %% [markdown]
# So it looks like Montrealers are commuter cyclists -- they bike much more during the week. Neat!
